# %% [markdown]
# <a href="https://colab.research.google.com/github/vikaspalaksh-art/Yolo-model-Training-code/blob/main/yolo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.6/46.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 8.5 MB/s eta 0:00:00
# ...

# %%
# !unzip -q apple.v1i.yolov8.zip -d /content/dataset
# Out:
# replace /content/dataset/train/images/Screenshot_15-9-2026_163659_www-bing-com_jpeg.rf.6d3db1213e510280f8eea0ffc1184cdf.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
with open('/content/dataset/data.yaml', 'r') as f:
    print(f.read())
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['apple']
#
# roboflow:
#   workspace: hitesh-infinite
#   project: apple-pfgnk
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/hitesh-infinite/apple-pfgnk/dataset/1

# %%
import yaml

yaml_path = '/content/dataset/data.yaml'

with open(yaml_path, 'r') as f:
    data = yaml.safe_load(f)

# Set absolute path to your dataset root
data['path'] = '/content/dataset'
data['train'] = 'train/images'
# If you don't have a separate 'valid' folder, use train images for validation:
data['val'] = 'train/images'

with open(yaml_path, 'w') as f:
    yaml.safe_dump(data, f)

print("Updated data.yaml:")
with open(yaml_path, 'r') as f:
    print(f.read())
# Out:
# Updated data.yaml:
# names:
# - apple
# nc: 1
# path: /content/dataset
# roboflow:
#   license: CC BY 4.0
#   project: apple-pfgnk
#   url: https://universe.roboflow.com/hitesh-infinite/apple-pfgnk/dataset/1
#   version: 1
#   workspace: hitesh-infinite
# test: ../test/images
# train: train/images
# val: train/images

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/dataset/data.yaml epochs=25 imgsz=640 batch=16
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/usage/settings.
# ...
# Ultralytics 8.4.153 🚀 Python-3.13.15 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
